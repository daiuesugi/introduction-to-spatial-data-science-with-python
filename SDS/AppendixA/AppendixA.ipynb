# %%
print('Hello World!')
# Out:
# Hello World!

# %%
a = 3
b = 5

# %%
c = a + b
print(c)
# Out:
# 8

# %%
import numpy as np

# %%
a = np.array([[1, 2, 3], [2, 3, 4]])
print(a)
b = np.array([[3, 4, 5], [4, 5, 6]])
print(b)
# Out:
# [[1 2 3]
#  [2 3 4]]
# [[3 4 5]
#  [4 5 6]]

# %%
c = a + b
print(c)
# Out:
# [[ 4  6  8]
#  [ 6  8 10]]

# %%
c = a * b
print(c)
# Out:
# [[ 3  8 15]
#  [ 8 15 24]]
